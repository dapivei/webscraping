# %% [markdown]
# # Colecting  tweets

# %% [markdown]
# + Librerías necesarias

# %%
#!pip3 install GetOldTweets3

# %%
import GetOldTweets3 as got
import pandas as pd

# %% [markdown]
# ### First search, without date criterion

# %%
username = 'nperedo' #restricted to an specific username
count = 100 #number of tweets

# %%
# Creation of query object
tweetCriteria = got.manager.TweetCriteria().setUsername(username).setMaxTweets(count)
# Creation of list that contains all tweets
tweets = got.manager.TweetManager.getTweets(tweetCriteria)# Creating list of chosen tweet data
user_tweets = [[tweet.date, tweet.text] for tweet in tweets]

# %%
df = pd.DataFrame(data=user_tweets, 
                    columns=['date_time', "tweet"])
df['date'] = df['date_time'].dt.date
df['time'] = df['date_time'].dt.time
df
# Out:
#                    date_time  \
# 0  2020-03-16 22:46:36+00:00
# 1  2020-03-12 16:15:14+00:00
# 2  2020-03-05 15:06:42+00:00
# 3  2020-03-04 20:18:10+00:00
# 4  2020-02-26 23:54:21+00:00
# 5  2020-02-21 00:56:55+00:00
# 6  2020-02-12 18:06:33+00:00
# 7  2020-02-09 14:51:30+00:00
# 8  2020-01-29 21:18:26+00:00
# 9  2020-01-25 05:14:17+00:00
# 10 2020-01-25 02:04:04+00:00
# 11 2020-01-24 19:48:36+00:00
# 12 2020-01-21 22:55:06+00:00
# 13 2020-01-20 16:44:53+00:00
# 14 2020-01-19 21:57:33+00:00
# 15 2020-01-17 23:01:36+00:00
# 16 2020-01-15 13:13:59+00:00
# 17 2019-12-31 01:30:46+00:00
# 18 2019-12-26 20:23:13+00:00
# 19 2019-12-24 19:14:47+00:00
# 20 2019-12-19 18:20:02+00:00
# 21 2019-12-07 14:55:36+00:00
# 22 2019-12-04 21:16:22+00:00
# 23 2019-12-04 01:17:44+00:00
# 24 2019-11-27 00:49:43+00:00
# 25 2019-11-15 19:13:33+00:00
# 26 2019-11-15 17:46:27+00:00
# 27 2019-11-14 19:01:05+00:00
# 28 2019-10-28 21:41:20+00:00
# 29 2019-10-27 17:47:22+00:00
# ..                       ...
# ...

# %% [markdown]
# ## Second search, with daterange criterion

# %%
username = 'nperedo'
since_date = '2019-04-23'
until_date = '2020-05-01'
count = 100

# %%
tweetCriteria = got.manager.TweetCriteria().setUsername(username).setSince(since_date).setUntil(until_date)# Creation of list that contains all tweets
tweets = got.manager.TweetManager.getTweets(tweetCriteria)# Creating list of chosen tweet data
# Creating list of chosen tweet data
user_tweets = [[tweet.date, tweet.text] for tweet in tweets]

# %%
df = pd.DataFrame(data=user_tweets, 
                    columns=['date_time', "tweet"])
df['date'] = df['date_time'].dt.date
df['time'] = df['date_time'].dt.time
df
# Out:
#                    date_time  \
# 0  2020-03-16 22:46:36+00:00
# 1  2020-03-12 16:15:14+00:00
# 2  2020-03-05 15:06:42+00:00
# 3  2020-03-04 20:18:10+00:00
# 4  2020-02-26 23:54:21+00:00
# 5  2020-02-21 00:56:55+00:00
# 6  2020-02-12 18:06:33+00:00
# 7  2020-02-09 14:51:30+00:00
# 8  2020-01-29 21:18:26+00:00
# 9  2020-01-25 05:14:17+00:00
# 10 2020-01-25 02:04:04+00:00
# 11 2020-01-24 19:48:36+00:00
# 12 2020-01-21 22:55:06+00:00
# 13 2020-01-20 16:44:53+00:00
# 14 2020-01-19 21:57:33+00:00
# 15 2020-01-17 23:01:36+00:00
# 16 2020-01-15 13:13:59+00:00
# 17 2019-12-31 01:30:46+00:00
# 18 2019-12-26 20:23:13+00:00
# 19 2019-12-24 19:14:47+00:00
# 20 2019-12-19 18:20:02+00:00
# 21 2019-12-07 14:55:36+00:00
# 22 2019-12-04 21:16:22+00:00
# 23 2019-12-04 01:17:44+00:00
# 24 2019-11-27 00:49:43+00:00
# 25 2019-11-15 19:13:33+00:00
# 26 2019-11-15 17:46:27+00:00
# 27 2019-11-14 19:01:05+00:00
# 28 2019-10-28 21:41:20+00:00
# 29 2019-10-27 17:47:22+00:00
# 30 2019-10-26 01:48:22+00:00
# ...

# %% [markdown]
# ### Saving output in a csv

# %%
file_name="tweet_search" #define name of file
df.to_csv(file_name, sep='\t')
